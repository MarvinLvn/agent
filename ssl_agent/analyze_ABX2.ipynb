# %%
import sys

sys.path.append("..")

from pathlib import Path
import pandas as pd

from ssl_agent.ssl_agent import SSLAgent
from lib.dataset_wrapper import Dataset
from lib import abx_utils
import torch
import numpy as np

torch.cuda.empty_cache()

ABX_NB_SAMPLES = 500
AGENT_ABX_DISTANCES = [
    {
        "art_estimated": {
            "metric": "cosine",
            "weight": 1,
        }
    },
    {
        "feat_seq": {
            "metric": "cosine",
            "weight": 1,
        }
    }
]


def compute_custom_ABX(agent_path, kind):
    assert kind in ['heldout', 'test']
    save_path = agent_path / 'results' / f'test_ABX_{kind}.csv'
    save_path.parent.mkdir(exist_ok=True)

    if not save_path.is_file():
        agent = SSLAgent.reload(str(agent_path))

        main_dataset = Dataset(kind)
        agent.config['dataset']['name'] = kind
        agent_lab = agent.get_datasplit_lab()
        speakers = np.unique([e.split('_')[0] for e in agent_lab[kind].keys()])
        consonants = main_dataset.phones_infos["consonants"]
        vowels = main_dataset.phones_infos["vowels"]
        consonants_indexes = abx_utils.get_datasets_phones_indexes(agent_lab, consonants, vowels)
        agent_features = agent.repeat_datasplit()
        out = {}
        for distance in AGENT_ABX_DISTANCES:
            for speaker in speakers:
                speaker_consonants_indexes = {
                    phone: [tup for tup in consonants_indexes[phone] if tup[1].split('_')[0] == speaker]
                    for phone in consonants_indexes.keys()
                }
                speaker_agent_features = {kind: {}}
                for feat_type, items_dict in agent_features[kind].items():
                    speaker_agent_features[kind][feat_type] = {k: v for k, v in items_dict.items() if k.startswith(speaker)}
                abx_matrix = abx_utils.get_abx_matrix(consonants, speaker_consonants_indexes, speaker_agent_features,
                                                      distance, ABX_NB_SAMPLES, seed=0)
                groups_score = abx_utils.get_groups_score(consonants, abx_matrix,
                                                          main_dataset.phones_infos["consonant_groups"])
                global_score = abx_utils.get_global_score(abx_matrix)
                distance_name = list(distance.keys())[0]
                scores = {f'{speaker}_place_{distance_name}': groups_score['place'],
                          f'{speaker}_manner_{distance_name}': groups_score['manner'],
                          f'{speaker}_global_{distance_name}': global_score}
                out = {**out, **scores}
        out = pd.DataFrame.from_dict([out])
        out.to_csv(save_path, index=False)
    else:
        print("Already done")
# Out:
# /home/engaclew/miniconda3/envs/agent/lib/python3.8/site-packages/torchaudio/backend/utils.py:53: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   warnings.warn(

# %%
agent_folder = Path('../out/ssl_agent/cosine/8_speakers_6000_mn')

# Compute cosine agents (MFCC and wav2vec 2.0)
for seed in range(0, 5):
    compute_custom_ABX(agent_folder / f'8_speakers_6000_mn_mfcc_delta_delta2_cosine_seed_{seed}', kind='heldout')
    compute_custom_ABX(agent_folder / f'8_speakers_6000_mn_mfcc_delta_delta2_cosine_seed_{seed}', kind='test')

for seed in range(0, 1):
    for i in range(0, 13):
        agent_name = f'8_speakers_6000_mn_layer_{i}_cosine_seed_{seed}'
        agent_path = agent_folder / agent_name
        compute_custom_ABX(agent_path, kind='heldout')
        compute_custom_ABX(agent_path, kind='test')
# Out:
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done
# Already done

# %%
# Load MFCC agent
baseline_cosine_8_speakers = {
    'mfcc_agent': { 
        'heldout': {},
        'test': {},
        'pb2009': {}
    }
}
    
for seed in range(0, 5):
    agent_name = f'8_speakers_6000_mn_mfcc_delta_delta2_cosine_seed_{seed}'
    for kind in ['heldout', 'test', 'pb2009']:
        agent_path = agent_folder / agent_name / 'results' / f'test_ABX_{kind}.csv'
        res = pd.read_csv(agent_path).to_dict('list')
        res = {k:v[0] for k, v in res.items()}
        for k, v in res.items():
            if k in baseline_cosine_8_speakers['mfcc_agent']:
                baseline_cosine_8_speakers['mfcc_agent'][kind][k].append(v)
            else:
                baseline_cosine_8_speakers['mfcc_agent'][kind][k] = [v]

# Load wav2vec 2.0 agent
w2v_cosine_8_speakers = {
    f'ssl_agent_layer_{i}': {
        'heldout': {},
        'test': {},
        'pb2009': {}
    }
    for i in range(0,13)
}

for seed in range(0, 1):
    for i in range(0, 13):
        for kind in ['heldout', 'test', 'pb2009']:
            agent_name = f'8_speakers_6000_mn_layer_{i}_cosine_seed_{seed}'
            agent_path = agent_folder / agent_name / 'results' / f'test_ABX_{kind}.csv'
            res = pd.read_csv(agent_path).to_dict('list')
            res = {k:v[0] for k, v in res.items()}
            for k, v in res.items():
                if k in w2v_cosine_8_speakers[f'ssl_agent_layer_{i}']:
                    w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][k].append(v)
                else:
                    w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][k] = [v]

keys = ['place_art_estimated', 'manner_art_estimated', 'global_art_estimated', 
        'place_feat_seq', 'manner_feat_seq', 'global_feat_seq']
for kind in ['heldout', 'test']:
    speakers =  np.unique([key.split('_')[0] for key in baseline_cosine_8_speakers['mfcc_agent'][kind].keys()])
    for key in keys:
        baseline_cosine_8_speakers['mfcc_agent'][kind][f'ave_{key}'] = [np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][f'{speaker}_{key}']) 
                                                                                 for speaker in speakers]
        for i in range(0, 13):
            w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][f'ave_{key}'] = [np.mean(w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][f'{speaker}_{key}']) 
                                                                                 for speaker in speakers]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import gridspec
import math
import pandas as pd

matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['font.serif'] = 'Arial'
matplotlib.rcParams.update({'font.size': 14, 'legend.handleheight':1, 'hatch.linewidth': 1.0,
                           'lines.markersize':5, 'lines.linewidth':2, 'errorbar.capsize': 5})

cepstrum_color = '#E69F00'
real_art_color = '#0072B2'
learned_art_color = '#009E73'

cm = 1/2.54
kind = 'test'

# Plot ABX place
fig = plt.figure(figsize=(14.5*cm,9.04*cm), constrained_layout=True)
gs = gridspec.GridSpec(2, 5, figure=fig, height_ratios=[1,10])
ax1 = fig.add_subplot(gs[1, 0])
ax2 = fig.add_subplot(gs[1, 1:])
ax_legend = fig.add_subplot(gs[0, :])
ax_legend.axis('off')

# 1. (MFCC agent) Learned articulatory trajectories
key = 'ave_place_art_estimated'
Y = np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][key])
Yerr = np.std(baseline_cosine_8_speakers['mfcc_agent'][kind][key], ddof=1)
X = [0.5]
ax1.bar(X, Y, yerr=Yerr, linewidth=2, color='white', ecolor=learned_art_color, edgecolor=learned_art_color)

# 2. (MFCC agent) MFCCs
key = 'ave_place_feat_seq'
Yb = np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][key])
ax1.axhline(Yb, color=cepstrum_color)
ax1.set_ylim(min(Y - 2*Yerr, Yb), max(Y + 2*Yerr, Yb)) 

# 1. (wav2vec 2.0 agent) Learned articulatory trajectories
key = 'ave_place_art_estimated'
Y = [np.mean(w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][key]) for i in range(0,13)]
Yerr = [np.std(w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][key], ddof=1) for i in range(0,13)]
X = range(0, len(Y))
ax2.errorbar(X, Y, yerr=Yerr, color=learned_art_color)
ax2.set_xticks(range(0, 13, 2))

# 2. (wav2vec 2.0 agent) MFCCs
key = 'ave_place_feat_seq'
Y = np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][key])
ax2.axhline(Y, color=cepstrum_color)

# Fashion
ax1.set_axisbelow(True)
ax2.set_axisbelow(True)
ax1.grid(visible=True, axis='y', linestyle=':', zorder=0)
ax2.grid(visible=True, axis='y', linestyle=':', zorder=0)

ax1.set_xticks([])
ax2.tick_params(axis='y', which='both', left=False, labelleft=False)
ymin = min(ax1.get_ylim()[0], ax2.get_ylim()[0])
ymax = max(ax1.get_ylim()[1], ax2.get_ylim()[1])
ax2.set_ylim(ymin, ymax)
ax1.set_ylim(ymin, ymax)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

ax1.set_ylabel('Place of articulation\nABX score (%)')
ax2.set_xlabel('wav2vec 2.0 space\n(layer number)')
ax1.set_xlabel('MFCC\nspace', labelpad=24)
ax1.set_xlim(0, 1)

legend_elements = [
    plt.Line2D([0], [0], color=learned_art_color, lw=2, label='Learned art.'),
    plt.Line2D([0], [0], color=cepstrum_color, lw=2, label='Gold cepstrum')
]

ax_legend.legend(handles=legend_elements, bbox_to_anchor=(.9, 0.5), ncol=3, fontsize=13, columnspacing=.8)
plt.savefig('/home/engaclew/agent/out/ssl_agent/8_speakers_6000_mn_abx_place_cosine_test.png', dpi=300)
plt.show()

# %%
# ABX manner/global on heldout/test
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import gridspec
import math
import pandas as pd

matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['font.serif'] = 'Arial'
matplotlib.rcParams.update({'font.size': 14, 'legend.handleheight':1, 'hatch.linewidth': 1.0,
                           'lines.markersize':5, 'lines.linewidth':2, 'errorbar.capsize': 5})

cepstrum_color = '#E69F00'
real_art_color = '#0072B2'
learned_art_color = '#009E73'

cm = 1/2.54
kind = 'test'

# Plot ABX place
fig = plt.figure(figsize=(14.5*cm,9.04*cm), constrained_layout=True)
gs = gridspec.GridSpec(2, 5, figure=fig, height_ratios=[1,10])
ax1 = fig.add_subplot(gs[1, 0])
ax2 = fig.add_subplot(gs[1, 1:])
ax_legend = fig.add_subplot(gs[0, :])
ax_legend.axis('off')

# 1. (MFCC agent) Learned articulatory trajectories
key = 'ave_global_art_estimated'
Y = np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][key])
Yerr = np.std(baseline_cosine_8_speakers['mfcc_agent'][kind][key], ddof=1)
X = [0.5]
ax1.bar(X, Y, yerr=Yerr, linewidth=2, color='white', ecolor=learned_art_color, edgecolor=learned_art_color)
            
# 2. (MFCC agent) MFCCs
key = 'ave_global_feat_seq'
Yb = np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][key])
ax1.axhline(Yb, color=cepstrum_color)
ax1.set_ylim(min(Y - 2*Yerr, Yb), max(Y + 2*Yerr, Yb)) 

# 1. (wav2vec 2.0 agent) Learned articulatory trajectories
key = 'ave_global_art_estimated'
Y = [np.mean(w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][key]) for i in range(0,13)]
Yerr = [np.std(w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][key], ddof=1) for i in range(0,13)]
X = range(0, len(Y))
ax2.errorbar(X, Y, yerr=Yerr, color=learned_art_color)
ax2.set_xticks(X)

# 2. (wav2vec 2.0 agent) MFCCs
key = 'ave_global_feat_seq'
Y = np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][key])
ax2.axhline(Y, color=cepstrum_color)

# Fashion
ax1.set_axisbelow(True)
ax2.set_axisbelow(True)
ax1.grid(visible=True, axis='y', linestyle=':', zorder=0)
ax2.grid(visible=True, axis='y', linestyle=':', zorder=0)

ax1.set_xticks([])
ymin = min(ax1.get_ylim()[0], ax2.get_ylim()[0])
ymax = max(ax1.get_ylim()[1], ax2.get_ylim()[1])
ax2.set_ylim(ymin, ymax)
ax1.set_ylim(ymin, ymax)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

ax1.set_ylabel('Test ABX global (%)')
ax2.set_xlabel('Layer number\n(wav2vec 2.0 agent)')
ax1.set_xlabel('MFCC\nagent', labelpad=24)
ax1.set_xlim(0, 1)

legend_elements = [
    plt.Line2D([0], [0], color=learned_art_color, lw=2, label='Learned art.'),
    plt.Line2D([0], [0], color=cepstrum_color, lw=2, label='Gold cepstrum')
]

ax_legend.legend(handles=legend_elements, bbox_to_anchor=(1.02, 0.5), ncol=3, fontsize=13, columnspacing=.8)
plt.savefig('/home/engaclew/agent/out/ssl_agent/8_speakers_6000_mn_abx_manner_cosine_test.png', dpi=300)
plt.show()

# %%
# ABX place/manner/global on pb2009
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import gridspec
import math
import pandas as pd

matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['font.serif'] = 'Arial'
matplotlib.rcParams.update({'font.size': 14, 'legend.handleheight':1, 'hatch.linewidth': 1.0,
                           'lines.markersize':5, 'lines.linewidth':2, 'errorbar.capsize': 5})

cepstrum_color = '#E69F00'
real_art_color = '#0072B2'
learned_art_color = '#009E73'

cm = 1/2.54
kind = 'pb2009'

# Plot ABX place
fig = plt.figure(figsize=(14.5*cm,9.04*cm), constrained_layout=True)
gs = gridspec.GridSpec(2, 5, figure=fig, height_ratios=[1,10])
ax1 = fig.add_subplot(gs[1, 0])
ax2 = fig.add_subplot(gs[1, 1:])
ax_legend = fig.add_subplot(gs[0, :])
ax_legend.axis('off')

# 1. (MFCC agent) Learned articulatory trajectories
key = 'place_art_estimated'
Y = np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][key])
Yerr = 0 #np.std(baseline_cosine_8_speakers['mfcc_agent'][kind][key], ddof=1)
X = [0.5]
ax1.bar(X, Y, yerr=Yerr, linewidth=2, color='white', ecolor=learned_art_color, edgecolor=learned_art_color)

# 2. (MFCC agent) MFCCs
key = 'place_feat_seq'
Yb = np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][key])
ax1.axhline(Yb, color=cepstrum_color)
ax1.set_ylim(min(Y - 2*Yerr, Yb)-5, max(Y + 2*Yerr, Yb)) 

# 1. (wav2vec 2.0 agent) Learned articulatory trajectories
key = 'place_art_estimated'
Y = [np.mean(w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][key]) for i in range(0,13)]
Yerr = [np.std(w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][key], ddof=1) for i in range(0,13)]
X = range(0, len(Y))
ax2.errorbar(X, Y, yerr=Yerr, color=learned_art_color)
ax2.set_xticks(X)

# 2. (wav2vec 2.0 agent) MFCCs
key = 'place_feat_seq'
Y = np.mean(baseline_cosine_8_speakers['mfcc_agent'][kind][key])
ax2.axhline(Y, color=cepstrum_color)

# Fashion
ax1.set_axisbelow(True)
ax2.set_axisbelow(True)
ax1.grid(visible=True, axis='y', linestyle=':', zorder=0)
ax2.grid(visible=True, axis='y', linestyle=':', zorder=0)

ax1.set_xticks([])
ax2.tick_params(axis='y', which='both', left=False, labelleft=False)
ymin = min(ax1.get_ylim()[0], ax2.get_ylim()[0])
ymax = max(ax1.get_ylim()[1], ax2.get_ylim()[1])
ax2.set_ylim(ymin, ymax)
ax1.set_ylim(ymin, ymax)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

ax1.set_ylabel('PB 2009 ABX place (%)')
ax2.set_xlabel('Layer number\n(wav2vec 2.0 agent)')
ax1.set_xlabel('MFCC\nagent', labelpad=24)
ax1.set_xlim(0, 1)

legend_elements = [
    plt.Line2D([0], [0], color=learned_art_color, lw=2, label='Learned art.'),
    plt.Line2D([0], [0], color=cepstrum_color, lw=2, label='Gold cepstrum')
]

ax_legend.legend(handles=legend_elements, bbox_to_anchor=(1.02, 0.5), ncol=3, fontsize=13, columnspacing=.8)
plt.savefig('/home/engaclew/agent/out/ssl_agent/8_speakers_6000_mn_abx_place_cosine_pb2009.png', dpi=300)
plt.show()

# %%
# What makes a good representational space

from pathlib import Path
import pandas as pd
import numpy as np
# Load wav2vec 2.0 agent
w2v_cosine_8_speakers = {
    f'ssl_agent_layer_{i}': {
        'test': {},
    }
    for i in range(0,13)
}

agent_folder = Path('../out/ssl_agent/cosine/8_speakers_6000_mn')

for seed in range(0, 1):
    for i in range(0, 13):
        for kind in ['test']:
            agent_name = f'8_speakers_6000_mn_layer_{i}_cosine_seed_{seed}'
            agent_path = agent_folder / agent_name / 'results' / f'test_ABX_{kind}.csv'
            res = pd.read_csv(agent_path).to_dict('list')
            res = {k:v[0] for k, v in res.items()}
            for k, v in res.items():
                if k in w2v_cosine_8_speakers[f'ssl_agent_layer_{i}']:
                    w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][k].append(v)
                else:
                    w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][k] = [v]

keys = ['place_art_estimated', 'manner_art_estimated', 'global_art_estimated', 
        'place_feat_seq', 'manner_feat_seq', 'global_feat_seq']
for kind in ['test']:
    speakers =  np.unique([key.split('_')[0] for key in w2v_cosine_8_speakers['ssl_agent_layer_0'][kind].keys()])
    for key in keys:
        for i in range(0, 13):
            w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][f'ave_{key}'] = np.mean([w2v_cosine_8_speakers[f'ssl_agent_layer_{i}'][kind][f'{speaker}_{key}'][0] 
                                                                                 for speaker in speakers])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import gridspec
import math
import pandas as pd
from scipy import stats
matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['font.serif'] = 'Arial'
matplotlib.rcParams.update({'font.size': 15, 'legend.handleheight':1, 'hatch.linewidth': 1.0,
                           'lines.markersize':5, 'lines.linewidth':2, 'errorbar.capsize': 5,
                           'xtick.labelsize': 12, 'ytick.labelsize': 12})

cm = 1/2.54
prob_color = '#CC79A7'
scatter_color = 'grey'

fig_width = 16.5 * cm
fig_height = 19.04 * cm
fig = plt.figure(figsize=(fig_width, fig_height), constrained_layout=True)
gs = gridspec.GridSpec(3, 2, figure=fig, height_ratios=[1,1,1], width_ratios=[3, 2])

# Create subplots
ax1, ax2 = fig.add_subplot(gs[0, 0]), fig.add_subplot(gs[0, 1])
ax3, ax4 = fig.add_subplot(gs[1, 0]), fig.add_subplot(gs[1, 1])
ax5, ax6 = fig.add_subplot(gs[2, 0]), fig.add_subplot(gs[2, 1])
# 1) ABX place
key = 'ave_place_feat_seq'
Y = [w2v_cosine_8_speakers[f'ssl_agent_layer_{i}']['test'][key] for i in range(0, 13)]
ax1.plot(Y, color=prob_color)
ax1.set_ylabel('ABX\n place (%)', labelpad=13)
ticks = ax1.get_yticks()
ylim = ax1.get_ylim()
abx_ticks = range(int((ylim[0] // 5) * 5), int(((ylim[1] // 5) + 1) * 5), 5)
ax1.set_yticks(abx_ticks)

key = 'ave_place_art_estimated'
X = [w2v_cosine_8_speakers[f'ssl_agent_layer_{i}']['test'][key] for i in range(0, 13)]
for i, (x, y) in enumerate(zip(X,Y)):
    if i == 8:
        ax2.scatter(x, y, color='red', s=100, alpha=.6)
    else:    
        ax2.scatter(x, y, color=scatter_color, s=100)
    ax2.text(x, y, s=i, fontsize=10, horizontalalignment='center', verticalalignment='center', color='white')
print(f"Pearson's R ABX place: {stats.pearsonr(X, Y)}")
xmin, xmax = ax2.get_xlim()
ymin, ymax = ax2.get_ylim()
both_min = np.min([xmin,ymin])
both_max = np.max([xmax,ymax])
ax2.set_xlim(both_min, both_max)
ax2.set_ylim(both_min, both_max)
x = np.linspace(both_min, both_max, 100)
ax2.plot(x, x, linestyle='--', color='black', alpha=.5)
ax2.text(1.0*both_min+9, 1.0*both_min+5, 'y = x', rotation=45, ha='center', va='center', alpha=.7)
ax2.set_xticks(abx_ticks)
ax2.set_yticks(abx_ticks)

# 2) Phone recognition

per = pd.read_csv('/home/engaclew/agent/out/PR_test.txt', header=None, sep=' ')
per.columns = ['layer', 'per']

Y = 100*(1-per['per'])
ax3.plot(Y, color=prob_color)
ax3.set_ylabel('Phone\n error rate (%)', labelpad=13)
ticks = ax3.get_yticks()
ax3.set_yticks(ticks)



X = [w2v_cosine_8_speakers[f'ssl_agent_layer_{i}']['test'][key] for i in range(0, 13)]

for i, (x, y) in enumerate(zip(X,Y)):
    if i == 8:
        ax4.scatter(x, y, color='red', s=100, alpha=.6)
    else:    
        ax4.scatter(x, y, color=scatter_color, s=100)
    ax4.text(x, y, s=i, fontsize=10, horizontalalignment='center', verticalalignment='center', color='white')
ax4.set_yticks(ticks)
ax4.set_xticks(abx_ticks)
print(f"Pearson's R phone error rate: {stats.pearsonr(X, Y)}")

# 3) Speaker recognition
acc = pd.read_csv('/home/engaclew/agent/out/SID_test.txt', header=None, sep=' ')
acc.columns = ['layer', 'acc']
ax5.set_ylabel('Speaker\n accuracy (%)')
ax5.set_xlabel('wav2vec 2.0\nlayer number')
Y = 100*acc['acc']
Y = [100 if e > 100 else e for e in Y]
ax5.plot(Y, color=prob_color)
ticks = ax5.get_yticks()

X = [w2v_cosine_8_speakers[f'ssl_agent_layer_{i}']['test'][key] for i in range(0, 13)]
for i, (x, y) in enumerate(zip(X,Y)):
    if i == 8:
        ax6.scatter(x, y, color='red', s=100, alpha=.6)
    else:
        ax6.scatter(x, y, color=scatter_color, s=100)
    ax6.text(x, y, s=i, fontsize=10, horizontalalignment='center', verticalalignment='center', color='white')
    
ax6.set_yticks(ticks)
ax6.set_xticks(abx_ticks)
print(f"Pearson's R speaker accuracy: {stats.pearsonr(X, Y)}")
ax6.set_xlabel('ABX place (%)\nlearned art. (6-D)') 
ax6.set_xticks(abx_ticks)

ylim = ax5.get_ylim()
ticks = list(range(int((ylim[0] // 10) * 10), int(((ylim[1] // 10) + 1) * 10), 10))
ax5.set_yticks(ticks)
ax6.set_yticks(ticks)
ax6.set_ylim(ylim)

for ax in ax1, ax3, ax5:
    ax.grid(visible=True, axis='y', linestyle=':', zorder=0)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.axvline(8, color='red', linestyle='--', alpha=.6)

xmin = np.max([ax2.get_xlim()[0], ax4.get_xlim()[0], ax6.get_xlim()[0]])
xmax = np.max([ax2.get_xlim()[1], ax4.get_xlim()[1], ax6.get_xlim()[1]])
for ax in ax2, ax4, ax6:
    ax.grid(visible=True, axis='both', linestyle=':', zorder=0)
    #ax.tick_params(axis='y', which='both', left=False, labelleft=False)
    ax.set_xlim(xmin, xmax)


for ax in ax1, ax3, ax5:
    ax.set_xticks(range(0, 13, 2))

#    ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)



#fig.text(-0.03, 0.5, 'Input wav2vec 2.0 representations (768-D)', va='center', rotation='vertical')
ax1.set_title('Input wav2vec 2.0\n representations (768-D)', fontsize=15)
ax2.set_title('Input/output\n correlations', fontsize=15)
plt.tight_layout()
plt.savefig('/home/engaclew/agent/out/ssl_agent/representational_space.png', dpi=400)
plt.show()
# Out:
# Pearson's R ABX place: (0.8327665065053343, 0.00040964451886836285)
# Pearson's R phone error rate: (0.9246296704159604, 6.1434292161370936e-06)
# Pearson's R speaker accuracy: (-0.8283686321115392, 0.0004682975786473942)
# /tmp/ipykernel_37835/2640111025.py:137: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   plt.tight_layout()

# %%
print((ylim[0] // 5) * 5)
print(((ylim[1] // 5) + 1) * 5)
print(ylim)
# Out:
# 60.0
# 85.0
# (63.664843749999996, 83.45911458333332)
